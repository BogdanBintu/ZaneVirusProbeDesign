# %% [markdown]
# LabTracks ID
#
# Available for Shipment
#
# Date Brains Frozen/Will Be Frozen
#
# Virus Injected
#
# Virus Full Name
#
# Notes
#
# 622674
#
# 04/21/22
#
# 04/19/22
#
# AiP1492
#
# pAAV-MGT_E4-minBGpromoter-SYFP2-WPRE-bGHpA
#
# CRA to ship completed
#
# 655892
#
# 12/01/22
#
# 11/30/22
#
# AiP11818 (CN1818)
#
# pAAV-3xCore_MGT_E4-minBGpromoter-SYFP2-WPRE-bGHpA
#
# CRA amendment to ship completed 6/1/23
#
# 655893
#
# 12/01/22
#
# 11/30/22
#
# AiP11818 (CN1818)
#
# pAAV-3xCore_MGT_E4-minBGpromoter-SYFP2-WPRE-bGHpA
#
# CRA amendment to ship completed 6/1/23
#
# 655904
#
# 12/03/22
#
# 12/02/22
#
# AiP1492
#
# pAAV-MGT_E4-minBGpromoter-SYFP2-WPRE-bGHpA
#
#
#
# 656797
#
# 12/09/22
#
# 12/08/22
#
# AiP1492
#
# pAAV-MGT_E4-minBGpromoter-SYFP2-WPRE-bGHpA
